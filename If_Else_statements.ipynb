# %% [markdown]
# <a href="https://colab.research.google.com/github/sardormamatqobulov1/Python_lesson/blob/main/If_Else_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 20

# %%
if age >= 18:
  print("You are an adult")
# Out:
# You are an adult

# %%
age = 15
if age >= 19:
  print("You are an adult")
else:
  print("You are a minor")
# Out:
# You are a minor

# %%
marks = 90

if marks >= 95:
  print("Grade: A")
elif marks >= 85:
  print("Grade: B")
elif marks >= 70:
  print("Grade: C")
else:
  print("Grade: F")
# Out:
# Grade: B

# %%
age = 20
has_id = True

if age >= 18:
  if has_id:
    print(" You can enter the club")
  else:
    print("You cannot enter without ID")
else:
  print("You are too young to enter")
# Out:
#  You can enter the club

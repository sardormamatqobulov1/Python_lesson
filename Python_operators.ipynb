# %% [markdown]
# <a href="https://colab.research.google.com/github/sardormamatqobulov1/Python_lesson/blob/main/Python_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 11
b = 4

# %%
print(a+b) #Addition
# Out:
# 15

# %%
print(a-b) #Subtraction
# Out:
# 7

# %%
print(a*b) #Multiplication
# Out:
# 44

# %%
print(a/b)#Division
# Out:
# 2.75

# %%
print(a%b) #Moduls
# Out:
# 3

# %%
#Comparison Operators
x = 5
y = 10

# %%
print(x == y)
# Out:
# False

# %%
print(x != y)
# Out:
# True

# %%
print(x > y)
# Out:
# False

# %%
print(x<y)
# Out:
# True

# %%
print(x>=y)
# Out:
# False

# %%
print(x<=y)
# Out:
# True

# %%
#Logical operators
age=25
salary= 1500

# %%
#AND
print(age>18 and salary > 1000)
# Out:
# True

# %%
#OR
print(age > 30 or salary > 1000)
# Out:
# True

# %%
#NOT
print(not age < 18)
# Out:
# True
